# %% [raw]
# <script>
#   jQuery(document).ready(function($) {
#
#   $(window).load(function(){
#     $('#preloader').fadeOut('slow',function(){$(this).remove();});
#   });
#
#   });
# </script>
#
# <style type="text/css">
#   div#preloader { position: fixed;
#       left: 0;
#       top: 0;
#       z-index: 999;
#       width: 100%;
#       height: 100%;
#       overflow: visible;
#       background: #fff url('http://preloaders.net/preloaders/720/Moving%20line.gif') no-repeat center center;
#   }
#
# </style>
#
# <div id="preloader"></div>

# %% [raw]
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %% [markdown]
# # Capstone Project: Analytic Report and Research Proposal
#
# __Three Goals:__
#
# 1. __Describe the dataset:__ What does the data contain and what is its background? Where does it come from? Why is it interesting or significant? Conduct summary statistics and produce visualizations for the particular variables from the dataset that is used.
#
#
# 2. __Ask and answer analytic questions:__ Ask three analytic questions and answer each one with a combination of statistics and visualizations. These analytic questions focuses on individuals behaviors or comparisons of the population.
#
#
# 3. __Propose further research:__ Make a proposal for a realistic future research project on this dataset that would use some data science techniques. Just like the earlier questions, the research proposal should present one or more clear questions. Then describe the techniques that would applied in order to arrive at an answer.
#
# See this [recent analysis on 2016 celebrity deaths](https://medium.com/@jasoncrease/was-2016-especially-dangerous-for-celebrities-79d79b9fae02) for an excellent example of data-driven story telling that presents a problem, explores data, and produces an answer.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('us-mass-shootings-last-50-years/dataset5.csv', encoding = "ISO-8859-1")
data.head()
# Out:
#    S#                                Title                Location  \
# 0   1           Texas church mass shooting  Sutherland Springs, TX
# 1   2  Walmart shooting in suburban Denver            Thornton, CO
# 2   3      Edgewood businees park shooting            Edgewood, MD
# 3   4        Las Vegas Strip mass shooting           Las Vegas, NV
# 4   5           San Francisco UPS shooting       San Francisco, CA
#
#          Date                                Incident Area  \
# 0   11/5/2017                                       Church
# 1   11/1/2017                                     Wal-Mart
# 2  10/18/2017                             Remodeling Store
# 3   10/1/2017  Las Vegas Strip Concert outside Mandala Bay
# 4   6/14/2017                                 UPS facility
#
#   Open/Close Location     Target    Cause  \
# 0               Close     random  unknown
# 1                Open     random  unknown
# 2               Close  coworkers  unknown
# ...

# %%
data.shape
# Out:
# (323, 21)

# %%
data.describe()
# Out:
#                S#  Fatalities     Injured  Total victims  Policeman Killed  \
# count  323.000000  323.000000  323.000000     323.000000        317.000000
# mean   162.000000    4.436533    6.176471      10.263158          0.129338
# std     93.386294    5.783208   29.889182      33.662309          0.610294
# min      1.000000    0.000000    0.000000       3.000000          0.000000
# 25%     81.500000    1.000000    1.000000       4.000000          0.000000
# 50%    162.000000    3.000000    3.000000       5.000000          0.000000
# 75%    242.500000    5.500000    5.000000       9.000000          0.000000
# max    323.000000   59.000000  527.000000     585.000000          5.000000
#
#        Employeed (Y/N)    Latitude   Longitude
# count        67.000000  303.000000  303.000000
# mean          0.626866   37.225076  -94.429539
# std           0.487288    5.536365   16.513296
# min           0.000000   21.325512 -161.792752
# 25%           0.000000   33.571459 -110.205485
# ...

# %%
data.tail(5)
# Out:
#       S#                           Title                Location        Date  \
# 318  319  Clara Barton Elementary School       Chicago, Illinois   1/17/1974
# 319  320    New Orleans Police Shootings  New Orleans, Louisiana  12/31/1972
# 320  321             St. Aloysius Church     Spokane, Washington  11/11/1971
# 321  322      Rose-Mar College of Beauty           Mesa, Arizona  11/12/1966
# 322  323   University of Texas at Austin           Austin, Texas    8/1/1966
#
#                       Incident Area Open/Close Location    Target      Cause  \
# 318  Clara Barton Elementary School               Close  Teachers      anger
# 319                             NaN                 NaN    random     psycho
# 320                          Church               Close    random  terrorism
# 321      Rose-Mar College of Beauty               Close    random  terrorism
# 322             University of Texas               Close    random  terrorism
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 323 entries, 0 to 322
# Data columns (total 21 columns):
# S#                      323 non-null int64
# Title                   323 non-null object
# Location                278 non-null object
# Date                    323 non-null object
# Incident Area           261 non-null object
# Open/Close Location     295 non-null object
# Target                  318 non-null object
# Cause                   246 non-null object
# Summary                 323 non-null object
# Fatalities              323 non-null int64
# Injured                 323 non-null int64
# Total victims           323 non-null int64
# Policeman Killed        317 non-null float64
# Age                     179 non-null object
# Employeed (Y/N)         67 non-null float64
# Employed at             41 non-null object
# Mental Health Issues    323 non-null object
# Race                    321 non-null object
# Gender                  323 non-null object
# ...

# %%
data.count()
# Out:
# S#                      323
# Title                   323
# Location                278
# Date                    323
# Incident Area           261
# Open/Close Location     295
# Target                  318
# Cause                   246
# Summary                 323
# Fatalities              323
# Injured                 323
# Total victims           323
# Policeman Killed        317
# Age                     179
# Employeed (Y/N)          67
# Employed at              41
# Mental Health Issues    323
# Race                    321
# Gender                  323
# Latitude                303
# Longitude               303
# dtype: int64

# %% [markdown]
# ## Describe the dataset:
#
# What does the data contain and what is its background? Where does it come from? Why is it interesting or significant? Conduct summary statistics and produce visualizations for the particular variables from the dataset that is used.
#
# The data contains information about mass shootings that has happened in US for last 50 years. It has 21 columns collecting information on the shooter, where it happened, how many people were injured or killed, who were the target and what was the cause. This dataset comes from Kaggle: US Mass Shootings - Last 50 years (1966-2017) created by Zeeshan-ul-hassan Usmani. The data source comes from Wikipedia, Mother Jones, Stanford, USA Today and other web sources. It is important to do research on this topic because I live here and I want to find insights that will help others understand root cause or how can we prevent gun violence like this.

# %% [markdown]
# ## Ask and answer analytic questions

# %% [markdown]
# ## Propose further research

# %% [raw]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#999; background:#fff;">
# Created with Jupyter, delivered by Fastly, rendered by Rackspace.
# </footer>
